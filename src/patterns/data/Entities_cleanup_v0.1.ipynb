# %%
import pandas as pd

data = pd.read_excel('Entities Summary View_v1.xlsx', sheet_name='Entities Summary View', na_values=['NaN'])
data['ID'] = "GCDE:"+data['ID'].astype(str).str.zfill(7)            # Add GCDE prefix and pad with zeros

data
# Out:
#                                                   Label            ID  \
# 0                                                   18F  GCDE:0005016
# 1                             2010 Land Cover Of Canada  GCDE:0004261
# 2                             2015 Land Cover Of Canada  GCDE:0004262
# 3           2022 Update to the GC Data Strategy Roadmap  GCDE:0005010
# 4                         AAFC Data Stewardship Network  GCDE:0005030
# ...                                                 ...           ...
# 1618                              Youth Digital Gateway  GCDE:0005165
# 1619  Youth Service and Learning Directorate - Polic...  GCDE:0001885
# 1620  Youth Service and Learning Directorate - Stake...  GCDE:0001887
# 1621  Youth Service and Learning Directorate - Suppo...  GCDE:0001884
# 1622                                   Yukon Government  GCDE:0001998
#
#       Count of Links Entity Short Form  \
# 0                  0               NaN
# 1                  1               NaN
# 2                  1               NaN
# 3                  8               NaN
# 4                  1               NaN
# ...              ...               ...
# 1618               0               NaN
# 1619               2               NaN
# 1620               2               NaN
# 1621               1               NaN
# 1622              14               NaN
#
#                                                    Tags  \
# 0                                          DataCentric
# 1                                   Climate, Geospatial
# 2                                   Climate, Geospatial
# 3     DataCentric , DigitalAmbition, DataTalent, Dig...
# 4                                       DataStewardship
# ...                                                 ...
# 1618                               DigitalTalent, Youth
# 1619                                          ESDC-DEMO
# 1620                                          ESDC-DEMO
# 1621                                          ESDC-DEMO
# 1622                     PTGovernment, Climate, OpenGov
#
#                           Type           SubType  \
# 0                Organizations            Teams
# 1                      Dataset  Web Map Services
# 2                      Dataset  Web Map Services
# 3     Projects and Initiatives               NaN
# 4                  Communities               NaN
# ...                        ...               ...
# 1618     Programs and Services               NaN
# 1619                     Teams               NaN
# 1620                     Teams               NaN
# 1621                     Teams               NaN
# 1622             Organizations  Other Government
#
#                                             Description              OrgClass  \
# 0     18F is a technology and design consultancy for...      Other Government
# 1                                    Geospatial Dataset  Government of Canada
# 2                                    Geospatial Dataset  Government of Canada
# 3                            To recognize the project.   GC Interdepartmental
# 4                                                   NaN  Government of Canada
# ...                                                 ...                   ...
# 1618  The Youth Digital Gateway helps young people p...  Government of Canada
# 1619                                                NaN                   NaN
# 1620                                                NaN                   NaN
# 1621                                                NaN                   NaN
# 1622                                                NaN                PT+ FN
#
#        OrgSubType  ... Contacts DigitalTalentSize  \
# 0             NaN  ...      NaN               NaN
# 1             NaN  ...      NaN               NaN
# 2             NaN  ...      NaN               NaN
# 3             NaN  ...      NaN               1.0
# 4             NaN  ...      NaN               NaN
# ...           ...  ...      ...               ...
# 1618          NaN  ...      NaN               1.0
# 1619  Directorate  ...      NaN               NaN
# 1620  Directorate  ...      NaN               NaN
# 1621  Directorate  ...      NaN               NaN
# 1622          NaN  ...      NaN               NaN
#
#              Entity To (from Connections - Entity From)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Report to the Clerk of Privy Council: A Data S...
# 4                                                   NaN
# ...                                                 ...
# 1618                                                NaN
# 1619            Program Innovation and Measurement Team
# 1620                              Digital Outreach Team
# 1621                                                NaN
# 1622  Pan-Canadian Framework on Clean Growth and Cli...
#
#              Entity From (from Connections - Entity To) ID Text  \
# 0                                                   NaN    5016
# 1                           Federal Geospatial Platform    4261
# 2                           Federal Geospatial Platform    4262
# 3     TBS - Office of the Chief Information Officer ...    5010
# 4               Agriculture and Agri-Food Canada (AAFC)    5030
# ...                                                 ...     ...
# 1618                                                NaN    5165
# 1619                                    Learning Branch    1885
# 1620                                    Learning Branch    1887
# 1621                                    Learning Branch    1884
# 1622             Canadian Open Government Working Group    1998
#
#      Entity Type Eng (from Type) Entity sub-type (from SubType)  \
# 0                  Organizations                         Teams
# 1                        Dataset               Web Map Services
# 2                        Dataset               Web Map Services
# 3       Projects and Initiatives                            NaN
# 4                    Communities                            NaN
# ...                          ...                            ...
# 1618       Programs and Services                            NaN
# 1619                       Teams                            NaN
# 1620                       Teams                            NaN
# 1621                       Teams                            NaN
# 1622               Organizations               Other Government
#
#       Name (from OrgClass) Name (from Portfolio)  \
# 0         Other Government                   NaN
# 1     Government of Canada                   NaN
# 2     Government of Canada                   NaN
# 3     GC Interdepartmental                   NaN
# 4     Government of Canada                   NaN
# ...                    ...                   ...
# 1618  Government of Canada                   NaN
# 1619                   NaN                   NaN
# 1620                   NaN                   NaN
# 1621                   NaN                   NaN
# 1622                PT+ FN                   NaN
#
#                                        Name (from Tags)
# 0                                          DataCentric
# 1                                   Climate, Geospatial
# 2                                   Climate, Geospatial
# 3     DataCentric , DigitalAmbition, DataTalent, Dig...
# 4                                       DataStewardship
# ...                                                 ...
# 1618                               DigitalTalent, Youth
# 1619                                          ESDC-DEMO
# 1620                                          ESDC-DEMO
# 1621                                          ESDC-DEMO
# 1622                     PTGovernment, Climate, OpenGov
#
# [1623 rows x 64 columns]

# %%
data[['Label', 'Entity Short Form', 'Tags', 'Type', 'SubType', 'Description', 'OrgClass', 'OrgSubType', 'Portfolio', 'URL', 'Source of Entry', 'Admin Notes', 'Data Provider', 'Record Status', 'Last Modified By', 'Created', 'French Entity Full Name', 'French Short Form', 'French Description', 'French URL']]
# Out:
#                                                   Label Entity Short Form  \
# 0                                                   18F               NaN
# 1                             2010 Land Cover Of Canada               NaN
# 2                             2015 Land Cover Of Canada               NaN
# 3           2022 Update to the GC Data Strategy Roadmap               NaN
# 4                         AAFC Data Stewardship Network               NaN
# ...                                                 ...               ...
# 1618                              Youth Digital Gateway               NaN
# 1619  Youth Service and Learning Directorate - Polic...               NaN
# 1620  Youth Service and Learning Directorate - Stake...               NaN
# 1621  Youth Service and Learning Directorate - Suppo...               NaN
# 1622                                   Yukon Government               NaN
#
#                                                    Tags  \
# 0                                          DataCentric
# 1                                   Climate, Geospatial
# 2                                   Climate, Geospatial
# 3     DataCentric , DigitalAmbition, DataTalent, Dig...
# 4                                       DataStewardship
# ...                                                 ...
# 1618                               DigitalTalent, Youth
# 1619                                          ESDC-DEMO
# 1620                                          ESDC-DEMO
# 1621                                          ESDC-DEMO
# 1622                     PTGovernment, Climate, OpenGov
#
#                           Type           SubType  \
# 0                Organizations            Teams
# 1                      Dataset  Web Map Services
# 2                      Dataset  Web Map Services
# 3     Projects and Initiatives               NaN
# 4                  Communities               NaN
# ...                        ...               ...
# 1618     Programs and Services               NaN
# 1619                     Teams               NaN
# 1620                     Teams               NaN
# 1621                     Teams               NaN
# 1622             Organizations  Other Government
#
#                                             Description              OrgClass  \
# 0     18F is a technology and design consultancy for...      Other Government
# 1                                    Geospatial Dataset  Government of Canada
# 2                                    Geospatial Dataset  Government of Canada
# 3                             To recognize the project.  GC Interdepartmental
# 4                                                   NaN  Government of Canada
# ...                                                 ...                   ...
# 1618  The Youth Digital Gateway helps young people p...  Government of Canada
# 1619                                                NaN                   NaN
# 1620                                                NaN                   NaN
# 1621                                                NaN                   NaN
# 1622                                                NaN                PT+ FN
#
#        OrgSubType Portfolio  \
# 0             NaN       NaN
# 1             NaN       NaN
# 2             NaN       NaN
# 3             NaN       NaN
# 4             NaN       NaN
# ...           ...       ...
# 1618          NaN       NaN
# 1619  Directorate       NaN
# 1620  Directorate       NaN
# 1621  Directorate       NaN
# 1622          NaN       NaN
#
#                                                     URL  \
# 0                                  https://18f.gsa.gov/
# 1     https://geoappext.nrcan.gc.ca/arcgis/rest/serv...
# 2     https://geoappext.nrcan.gc.ca/arcgis/rest/serv...
# 3             https://gcxgce.sharepoint.com/teams/0307
# 4                                                   NaN
# ...                                                 ...
# 1618        https://youth-jeunesse.service.canada.ca/en
# 1619                                                NaN
# 1620                                                NaN
# 1621                                                NaN
# 1622                                                NaN
#
#                         Source of Entry                     Admin Notes  \
# 0                                   NaN                             NaN
# 1                              From FGP  Supports OSDP - Land Cover Map
# 2                              From FGP  Supports OSDP - Land Cover Map
# 3                                   NaN                             NaN
# 4                Data Stewardship Quest                             NaN
# ...                                 ...                             ...
# 1618  Sept 14 2022 Digital Talent Quest                             NaN
# 1619                                NaN                             NaN
# 1620                                NaN                             NaN
# 1621                                NaN                             NaN
# 1622                                NaN                             NaN
#
#      Data Provider            Record Status Last Modified By    Created  \
# 0              NaN  Essential data complete     Thom Kearney   6/9/2022
# 1              NaN                   Legacy     Thom Kearney  2/11/2022
# 2              NaN                   Legacy     Thom Kearney  2/11/2022
# 3              NaN  Essential data complete     Thom Kearney   6/8/2022
# 4              NaN  Essential data complete     Thom Kearney  6/17/2022
# ...            ...                      ...              ...        ...
# 1618           NaN  Essential data complete     Thom Kearney  9/26/2022
# 1619           NaN                   Legacy     Thom Kearney  10/6/2021
# 1620           NaN                   Legacy     Thom Kearney  10/6/2021
# 1621           NaN                   Legacy     Thom Kearney  10/6/2021
# 1622           NaN                   Legacy     Thom Kearney  12/6/2021
#
#      French Entity Full Name  French Short Form French Description French URL
# 0                        NaN                NaN                NaN        NaN
# 1                        NaN                NaN                NaN        NaN
# 2                        NaN                NaN                NaN        NaN
# 3                        NaN                NaN                NaN        NaN
# 4                        NaN                NaN                NaN        NaN
# ...                      ...                ...                ...        ...
# 1618                     NaN                NaN                NaN        NaN
# 1619                     NaN                NaN                NaN        NaN
# 1620                     NaN                NaN                NaN        NaN
# 1621                     NaN                NaN                NaN        NaN
# 1622   Gouvernement du Yukon                NaN                NaN        NaN
#
# [1623 rows x 20 columns]

# %%
# Remove newlines
data['Description'].str.replace('\n', ' ')
# Out:
# 0       18F is a technology and design consultancy for...
# 1                                      Geospatial Dataset
# 2                                      Geospatial Dataset
# 3                              To recognize the project.
# 4                                                     NaN
#                               ...
# 1618    The Youth Digital Gateway helps young people p...
# 1619                                                  NaN
# 1620                                                  NaN
# 1621                                                  NaN
# 1622                                                  NaN
# Name: Description, Length: 1623, dtype: object

# %%
# desc - determine all special characters
desc = data['Description'].str.replace('[a-zA-Z0-9 .,]', '')[data['Description'].str.replace('[a-zA-Z0-9 .,]', '').notna()]
desc
# Out:
# /tmp/ipykernel_1598284/2096858017.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   desc = data['Description'].str.replace('[a-zA-Z0-9 .,]', '')[data['Description'].str.replace('[a-zA-Z0-9 .,]', '').notna()]
# 0         \n
# 1
# 2
# 3
# 5
#         ...
# 1608      ()
# 1613    --\n
# 1616
# 1617      --
# 1618    \n\n
# Name: Description, Length: 1336, dtype: object

# %%
spec_chars = ""
for i in desc:
    if i == "":
        continue
#    print(i)
    for j in i:
        if j not in spec_chars:
            spec_chars += j

print(spec_chars)

#TODO Use above to create a list of special characters to remove, except for the ones we want to keep
# only allow alphanumeric characters, special characters: .,() and space
# '+-:()/\'–$&!;‑"|°?€=£·#~±%@[]'

# https://stackoverflow.com/questions/1276764/stripping-everything-but-alphanumeric-chars-from-a-string-in-python/1280823#1280823
delchars = ''.join(spec_chars for c in map(chr, range(256)) if not c.isalnum() and c not in ' .,+-:()/\'–$&!;‑"|°?€=£·#~±%@[]')
del_map = str.maketrans('', '', delchars)

def remove_special_characters(text):
    return text.translate(del_map)

# Test
a = pd.Series(['a™', 'édf\nd', ' c   '])
print("Test:", a, a.str.replace('\n', ' ').apply(lambda x: remove_special_characters(x.strip()) if isinstance(x, str) else x), sep='\n')
# Out:
# +-:()_ /'–$’&!“”‘é;—•®ﬂÉ‑"|àè°	?â€™=£·#~±%@[]…\
# Test:
# 0        a™
# 1    édf\nd
# 2      c
# dtype: object
# 0       a
# 1    df d
# 2       c
# dtype: object

# %%
import re
#re.sub('[^a-zA-Z0-9 .,+-:()/\'–$&!;‑"|°?€=£·#~±%@[]]', '', data['Description'][724])
data['Description'].apply(lambda x: re.sub('[^a-zA-Z0-9 .,+-:()/\'–$&!;‑"|°?€=£·#~±%@[]]', '', str(x)))
# Out:
# 0       18F is a technology and design consultancy for...
# 1                                      Geospatial Dataset
# 2                                      Geospatial Dataset
# 3                              To recognize the project.
# 4                                                     nan
#                               ...
# 1618    The Youth Digital Gateway helps young people p...
# 1619                                                  nan
# 1620                                                  nan
# 1621                                                  nan
# 1622                                                  nan
# Name: Description, Length: 1623, dtype: object
